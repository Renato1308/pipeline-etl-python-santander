# %%
import pandas as pd

# 1. EXTRACT
data = {
    'Nome': ['Renato', 'Ana', 'Carlos'],
    'Conta': ['1001', '1002', '1003'],
    'Cartao': ['Visa', 'Master', 'Amex']
}
df = pd.DataFrame(data)

# 2. TRANSFORM
df['Mensagem'] = df['Nome'] + ", oferta especial no seu cartão " + df['Cartao']

# 3. LOAD
df.to_csv('resultado_santander.csv', index=False)
print("Pipeline executado com sucesso!")
print(df)
# Out:
# Pipeline executado com sucesso!
#      Nome Conta  Cartao                                    Mensagem
# 0  Renato  1001    Visa  Renato, oferta especial no seu cartão Visa
# 1     Ana  1002  Master   Ana, oferta especial no seu cartão Master
# 2  Carlos  1003    Amex  Carlos, oferta especial no seu cartão Amex
